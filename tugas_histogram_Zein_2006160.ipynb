# %% [markdown]
# <a href="https://colab.research.google.com/github/Zeinayyy/Zeinayyy/blob/main/tugas_histogram_Zein_2006160.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img = cv2.imread('/content/drive/MyDrive/Rapot/20220205_101737.jpg')
warna = cv2.cvtColor(cv2.imread('/content/drive/MyDrive/Rapot/20220205_101737.jpg'), cv2.COLOR_BGR2RGB)
plt.imshow(warna)

# %%
plt.hist(warna.ravel(),256,[0,256])
plt.show()

# %%
gray=cv2.cvtColor(warna, cv2.COLOR_RGB2GRAY)
plt.imshow(gray,cmap='gray')

# %%
plt.hist(gray.ravel(),256,[0,256])
plt.show()
